# %%
import numpy as np 
from scipy.integrate import odeint
import os, sys, warnings
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import utility as ut
import surrogate_nn as srnn
import surrogate1 as sr1
import matplotlib.pyplot as plt
import pandas as pd
import torch
from torch import nn
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, TensorDataset
from scipy import stats
warnings.filterwarnings('ignore')

# %% [markdown]
# **Loss and $\tau_f$ against iteration**

# %%
L63_data_path = '../data/L63-trajectories'
save_folder = '../data/nn_adaptive_lr_s'
D_r, N = 300, 20000
L0, L1 = 0.4, 3.5 
beta = 4e-5
train = np.load(f'{L63_data_path}/train.npy')[:, :N].astype(np.float64)
test = np.load(f'{L63_data_path}/test.npy')[:500, :, :800].astype(np.float64)
model = srnn.SurrogateModel_NN(3, 300, save_folder=save_folder)

idx = lambda x: ~np.isnan(x)

# %%
tau_f = np.load(f'{model.save_folder}/tau_f_se.npy')
loss = np.load(f'{model.save_folder}/loss.npy')
iteration = np.load(f'{model.save_folder}/iteration.npy')

# %%
fig = plt.figure(figsize=(10.5, 5))
ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
j = idx(tau_f)
ax.plot(iteration[j], tau_f[j])
ax1.plot(iteration[j], np.log(loss[j]))
ax.set_xlabel('gradient descent step', fontsize=11)
ax1.set_xlabel('gradient descent step', fontsize=11)
ax.set_ylabel(r'$\mathbb{E}[\tau_f]$', fontsize=13)
ax1.set_ylabel(r'$\log(\mathcal{L})$', fontsize=13)
fig.subplots_adjust(wspace=.25)
# fig.suptitle(r'$D_r=300, \beta=4\times10^{-5}, N=20000$')
plt.savefig('../data/plots/nn-tau_f-loss.png', dpi=300, bbox_inches='tight')

# %%
(tau_f[j][-1] - tau_f[j][-10]) / tau_f[j][-10], iteration[j][-10]
# Out:
# (0.0031949504198244072, 1400000)

# %%
fig = plt.figure(figsize=(10.5, 5))
ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)

x, y = np.log(loss[j])[6:], tau_f[j][6:]
ax.scatter(x, y, s=10)
res = stats.linregress(x, y)
a, b = res.slope, res.intercept
ax.plot(x, a*x+b, c='black', label=f'{a:.2f}'+r'$\log(\mathcal{L})+$'+f'{b:.2f}')
ax.locator_params(nbins=10, axis='x')
ax.legend(fontsize=11)
ax.set_xlabel('$\log(\mathcal{L})$', fontsize=11)
ax.set_ylabel(r'$\mathbb{E}[\tau_f]$', fontsize=13)
ax.set_title('Network')


bsa = sr1.BatchStrategyAnalyzer_SMLR('../data/standard-multi-valid')
data = bsa.get_data()
x, y = np.log(data['train_loss']), data['tau_f_se']
ax1.scatter(x, y, s=10)#, label=r'$\mathbb{E}[\tau_f]=$'+f'{y.mean():.2f}')

bin_means, bin_edges, binnumber = stats.binned_statistic(x, y, statistic='mean', bins=20)
centers = bin_edges[1:]
ax1.scatter(centers, bin_means, s=55, marker='x')
x, y = centers[:-1], bin_means[:-1]
mask = ~np.isnan(x) & ~np.isnan(y)
res = stats.linregress(x[mask], y[mask])
a, b = res.slope, res.intercept
ax1.plot(x, a*x+b, c='black', label=f'{a:.2f}'+r'$\log(\mathcal{L})+$'+f'{b:.2f}')
ax1.legend(fontsize=11)
ax1.set_xlabel('$\log(\mathcal{L})$', fontsize=11)
ax1.set_ylabel(r'$\mathbb{E}[\tau_f]$', fontsize=13)
ax1.set_title('Random feature map, $p_g=1$')
fig.subplots_adjust(wspace=.25)
# fig.suptitle(r'$D_r=300, \beta=4\times10^{-5}, N=20000$')
plt.savefig('../data/plots/scatter-tau_f-loss.png', dpi=300, bbox_inches='tight')

# %%
x, y
# Out:
# (array([0.08297465, 0.14244462, 0.20191458, 0.26138455, 0.32085452,
#         0.38032448, 0.43979445, 0.49926442, 0.55873438, 0.61820435,
#         0.67767432, 0.73714428, 0.79661425, 0.85608422, 0.91555418,
#         0.97502415, 1.03449412, 1.09396408, 1.15343405]),
#  array([5.0033802 , 4.88084567, 4.76377389, 4.7067748 , 4.6769788 ,
#         4.56488181, 4.60061714, 4.5710392 , 4.47966288, 4.40687392,
#         4.40467112, 4.18878333, 4.2472066 , 4.0830216 , 4.0994044 ,
#         3.96724813, 3.9479804 ,        nan, 3.93162467]))

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)

data = model.read()
ax.plot(iteration[j], D_r*data['good_rows_W_in'][j], label=r'$p_gD_r$')
ax.plot(iteration[j], D_r*data['linear_rows_W_in'][j], label=r'$p_lD_r$')
ax.plot(iteration[j], D_r*data['extreme_rows_W_in'][j], label=r'$p_sD_r$')
ax.legend(fontsize=11)
ax.set_ylabel('number of different types of rows', fontsize=11)
ax.set_xlabel('gradient descent step', fontsize=11)
plt.savefig('../data/plots/no-structure-formation.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig = plt.figure(figsize=(5, 5))
#       2 ax = fig.add_subplot(111)
#       4 data = model.read()
#
# NameError: name 'plt' is not defined

# %%
save_folder='../data/rf-start-lr1'
model1 = srnn.SurrogateModel_NN(3, 300, name='nn', save_folder=save_folder)
# model.init_with_rf(L0, L1, beta, train, partition=[300, 0, 0])
# model.learn(train[:, :20000], 20000, 1e-4, batch_size='GD', log_interval=10, save_interval=10)
model1.count_row_types(1, L0, L1, train.T)
# Out:
# Time taken by count_row_types is 3.8795 seconds

# %%
save_folder='../data/rf-start-lr2'
model2 = srnn.SurrogateModel_NN(3, 300, name='nn', save_folder=save_folder)
model2.init_with_rf(L0, L1, beta, train, partition=[300, 0, 0])
# model2.learn(train[:, :20000], 10000, 1e-3, batch_size='GD', log_interval=10, save_interval=10)
model2.count_row_types(1, L0, L1, train.T)
# Out:
# Time taken by count_row_types is 2.0284 seconds

# %%
fig = plt.figure(figsize=(10.5, 5))
ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)

model1 = srnn.SurrogateModel_NN(3, 300, name='nn', save_folder='../data/nn_rf_tiny_lr')
data1 = model1.read()
data2 = model2.read()

x = data1['iteration']
ax.plot(x, D_r*data1['good_rows_W_in'], label=r'$p_gD_r$')
ax.plot(x, D_r*data1['linear_rows_W_in'], label=r'$p_lD_r$')
ax.plot(x, D_r*data1['extreme_rows_W_in'], label=r'$p_sD_r$')
ax.locator_params(nbins=10, axis='x')
ax.legend(fontsize=11)
ax.set_ylabel('number of different types of rows', fontsize=11)
ax.set_xlabel('gradient descent step', fontsize=11)

x = data2['iteration']
ax1.plot(x, D_r*data2['good_rows_W_in'], label=r'$p_gD_r$')
ax1.plot(x, D_r*data2['linear_rows_W_in'], label=r'$p_lD_r$')
ax1.plot(x, D_r*data2['extreme_rows_W_in'], label=r'$p_sD_r$')
ax1.locator_params(nbins=10, axis='x')
ax1.legend(fontsize=11)
ax1.set_ylabel('number of different types of rows', fontsize=11)
ax1.set_xlabel('gradient descent step', fontsize=11)
fig.subplots_adjust(wspace=.25)
# fig.suptitle(r'$D_r=300, \beta=4\times10^{-5}, N=20000$')
plt.savefig('../data/plots/strcture-deletion.png', dpi=300, bbox_inches='tight')

# %%
model1.count_row_types(10, L0, L1, train.T)
# Out:
# Time taken by count_row_types is 23.9808 seconds

# %%
model_tlr = srnn.SurrogateModel_NN(3, 300, name='nn', save_folder='../data/nn_rf_tiny_lr')
model_tlr.compute_tau_f(100, train, test, end=100000)
# Out:
# working on index #0
# Time taken by compute_tau_f_ is 6.9513 seconds
# working on index #10000
# Time taken by compute_tau_f_ is 6.9153 seconds
# working on index #20000
# Time taken by compute_tau_f_ is 6.8770 seconds
# working on index #30000
# Time taken by compute_tau_f_ is 6.7555 seconds
# working on index #40000
# Time taken by compute_tau_f_ is 6.7745 seconds
# working on index #50000
# Time taken by compute_tau_f_ is 6.8763 seconds
# working on index #60000
# Time taken by compute_tau_f_ is 6.8485 seconds
# working on index #70000
# Time taken by compute_tau_f_ is 6.8027 seconds
# working on index #80000
# Time taken by compute_tau_f_ is 6.7311 seconds
# working on index #90000
# Time taken by compute_tau_f_ is 6.7297 seconds
# working on index #100000
# Time taken by compute_tau_f_ is 6.8069 seconds
# working on index #110000
# Time taken by compute_tau_f_ is 6.7786 seconds
# working on index #120000
# Time taken by compute_tau_f_ is 6.7266 seconds
# working on index #130000
# Time taken by compute_tau_f_ is 6.7237 seconds
# working on index #140000
# Time taken by compute_tau_f_ is 6.7295 seconds
# working on index #150000
# Time taken by compute_tau_f_ is 6.7728 seconds
# working on index #160000
# Time taken by compute_tau_f_ is 6.7595 seconds
# working on index #170000
# Time taken by compute_tau_f_ is 6.7323 seconds
# working on index #180000
# Time taken by compute_tau_f_ is 6.7248 seconds
# working on index #190000
# Time taken by compute_tau_f_ is 6.8288 seconds
# working on index #200000
# Time taken by compute_tau_f_ is 6.7376 seconds
# working on index #210000
# Time taken by compute_tau_f_ is 6.8088 seconds
# working on index #220000
# Time taken by compute_tau_f_ is 6.7985 seconds
# working on index #230000
# Time taken by compute_tau_f_ is 6.7263 seconds
# working on index #240000
# Time taken by compute_tau_f_ is 6.7400 seconds
# working on index #250000
# Time taken by compute_tau_f_ is 6.7741 seconds
# working on index #260000
# Time taken by compute_tau_f_ is 6.7392 seconds
# working on index #270000
# Time taken by compute_tau_f_ is 6.6978 seconds
# working on index #280000
# Time taken by compute_tau_f_ is 6.6972 seconds
# working on index #290000
# Time taken by compute_tau_f_ is 6.7015 seconds
# working on index #300000
# Time taken by compute_tau_f_ is 6.7279 seconds
# working on index #310000
# Time taken by compute_tau_f_ is 6.7785 seconds
# working on index #320000
# Time taken by compute_tau_f_ is 6.7225 seconds
# working on index #330000
# Time taken by compute_tau_f_ is 6.6963 seconds
# working on index #340000
# Time taken by compute_tau_f_ is 6.7210 seconds
# working on index #350000
# Time taken by compute_tau_f_ is 6.6761 seconds
# working on index #360000
# Time taken by compute_tau_f_ is 6.7163 seconds
# working on index #370000
# Time taken by compute_tau_f_ is 6.7392 seconds
# working on index #380000
# Time taken by compute_tau_f_ is 6.7524 seconds
# working on index #390000
# Time taken by compute_tau_f_ is 6.7883 seconds
# working on index #400000
# Time taken by compute_tau_f_ is 6.8376 seconds
# working on index #410000
# Time taken by compute_tau_f_ is 6.9274 seconds
# working on index #420000
# Time taken by compute_tau_f_ is 6.7557 seconds
# working on index #430000
# Time taken by compute_tau_f_ is 6.8782 seconds
# working on index #440000
# Time taken by compute_tau_f_ is 6.7588 seconds
# working on index #450000
# Time taken by compute_tau_f_ is 6.7985 seconds
# working on index #460000
# Time taken by compute_tau_f_ is 6.8156 seconds
# working on index #470000
# Time taken by compute_tau_f_ is 6.7663 seconds
# working on index #480000
# Time taken by compute_tau_f_ is 6.7571 seconds
# working on index #490000
# Time taken by compute_tau_f_ is 6.8265 seconds
# working on index #500000
# Time taken by compute_tau_f_ is 6.7946 seconds
# working on index #510000
# Time taken by compute_tau_f_ is 6.7659 seconds
# working on index #520000
# Time taken by compute_tau_f_ is 6.7052 seconds
# working on index #530000
# Time taken by compute_tau_f_ is 6.7222 seconds
# working on index #540000
# Time taken by compute_tau_f_ is 6.7092 seconds
# working on index #550000
# Time taken by compute_tau_f_ is 6.7207 seconds
# working on index #560000
# Time taken by compute_tau_f_ is 6.7983 seconds
# working on index #570000
# Time taken by compute_tau_f_ is 6.7686 seconds
# working on index #580000
# Time taken by compute_tau_f_ is 6.7866 seconds
# working on index #590000
# Time taken by compute_tau_f_ is 6.8343 seconds
# working on index #600000
# Time taken by compute_tau_f_ is 6.7358 seconds
# working on index #610000
# Time taken by compute_tau_f_ is 6.7242 seconds
# working on index #620000
# Time taken by compute_tau_f_ is 6.7072 seconds
# working on index #630000
# Time taken by compute_tau_f_ is 6.7349 seconds
# working on index #640000
# Time taken by compute_tau_f_ is 6.7359 seconds
# working on index #650000
# Time taken by compute_tau_f_ is 6.7813 seconds
# working on index #660000
# Time taken by compute_tau_f_ is 6.7638 seconds
# working on index #670000
# Time taken by compute_tau_f_ is 6.7085 seconds
# working on index #680000
# Time taken by compute_tau_f_ is 6.8258 seconds
# working on index #690000
# Time taken by compute_tau_f_ is 6.7213 seconds
# working on index #700000
# Time taken by compute_tau_f_ is 6.7194 seconds
# working on index #710000
# Time taken by compute_tau_f_ is 6.7306 seconds
# working on index #720000
# Time taken by compute_tau_f_ is 6.8212 seconds
# working on index #730000
# Time taken by compute_tau_f_ is 6.8107 seconds
# working on index #740000
# Time taken by compute_tau_f_ is 6.7599 seconds
# working on index #750000
# Time taken by compute_tau_f_ is 6.7646 seconds
# working on index #760000
# Time taken by compute_tau_f_ is 6.7220 seconds
# working on index #770000
# Time taken by compute_tau_f_ is 6.7778 seconds
# working on index #780000
# Time taken by compute_tau_f_ is 6.8529 seconds
# working on index #790000
# Time taken by compute_tau_f_ is 6.7537 seconds
# working on index #800000
# Time taken by compute_tau_f_ is 6.8886 seconds
# working on index #810000
# Time taken by compute_tau_f_ is 6.8639 seconds
# working on index #820000
# Time taken by compute_tau_f_ is 6.7594 seconds
# working on index #830000
# Time taken by compute_tau_f_ is 6.7942 seconds
# working on index #840000
# Time taken by compute_tau_f_ is 6.8810 seconds
# working on index #850000
# Time taken by compute_tau_f_ is 6.8351 seconds
# working on index #860000
# Time taken by compute_tau_f_ is 6.8003 seconds
# working on index #870000
# Time taken by compute_tau_f_ is 6.7980 seconds
# working on index #880000
# Time taken by compute_tau_f_ is 6.8919 seconds
# working on index #890000
# Time taken by compute_tau_f_ is 6.7988 seconds
# working on index #900000
# Time taken by compute_tau_f_ is 6.7567 seconds
# working on index #910000
# Time taken by compute_tau_f_ is 6.7299 seconds
# working on index #920000
# Time taken by compute_tau_f_ is 6.7322 seconds
# working on index #930000
# Time taken by compute_tau_f_ is 6.6967 seconds
# working on index #940000
# Time taken by compute_tau_f_ is 6.7153 seconds
# working on index #950000
# Time taken by compute_tau_f_ is 6.7730 seconds
# working on index #960000
# Time taken by compute_tau_f_ is 6.8033 seconds
# working on index #970000
# Time taken by compute_tau_f_ is 6.7686 seconds
# working on index #980000
# Time taken by compute_tau_f_ is 6.7685 seconds
# working on index #990000
# Time taken by compute_tau_f_ is 6.7336 seconds
# working on index #1000000
# Time taken by compute_tau_f_ is 6.7101 seconds
# working on index #1010000
# Time taken by compute_tau_f_ is 6.7317 seconds
# working on index #1020000
# Time taken by compute_tau_f_ is 6.7151 seconds
# working on index #1030000
# Time taken by compute_tau_f_ is 6.6879 seconds
# working on index #1040000
# Time taken by compute_tau_f_ is 6.7235 seconds
# working on index #1050000
# Time taken by compute_tau_f_ is 6.7455 seconds
# working on index #1060000
# Time taken by compute_tau_f_ is 6.7646 seconds
# working on index #1070000
# Time taken by compute_tau_f_ is 6.7584 seconds
# working on index #1080000
# Time taken by compute_tau_f_ is 6.7524 seconds
# working on index #1090000
# Time taken by compute_tau_f_ is 6.8227 seconds
# working on index #1100000
# Time taken by compute_tau_f_ is 6.8725 seconds
# working on index #1110000
# Time taken by compute_tau_f_ is 6.7595 seconds
# working on index #1120000
# Time taken by compute_tau_f_ is 6.7354 seconds
# working on index #1130000
# Time taken by compute_tau_f_ is 6.8413 seconds
# working on index #1140000
# Time taken by compute_tau_f_ is 6.8395 seconds
# working on index #1150000
# Time taken by compute_tau_f_ is 6.7795 seconds
# working on index #1160000
# Time taken by compute_tau_f_ is 6.7357 seconds
# working on index #1170000
# Time taken by compute_tau_f_ is 6.9176 seconds
# working on index #1180000
# Time taken by compute_tau_f_ is 6.8159 seconds
# working on index #1190000
# Time taken by compute_tau_f_ is 6.7946 seconds
# working on index #1200000
# Time taken by compute_tau_f_ is 6.7441 seconds
# working on index #1210000
# Time taken by compute_tau_f_ is 6.7312 seconds
# working on index #1220000
# Time taken by compute_tau_f_ is 6.8694 seconds
# working on index #1230000
# Time taken by compute_tau_f_ is 6.8600 seconds
# working on index #1240000
# Time taken by compute_tau_f_ is 6.8416 seconds
# working on index #1250000
# Time taken by compute_tau_f_ is 6.7314 seconds
# working on index #1260000
# Time taken by compute_tau_f_ is 6.7587 seconds
# working on index #1270000
# Time taken by compute_tau_f_ is 6.8003 seconds
# working on index #1280000
# Time taken by compute_tau_f_ is 6.7961 seconds
# working on index #1290000
# Time taken by compute_tau_f_ is 6.7772 seconds
# working on index #1300000
# Time taken by compute_tau_f_ is 6.7554 seconds
# working on index #1310000
# Time taken by compute_tau_f_ is 6.7898 seconds
# working on index #1320000
# Time taken by compute_tau_f_ is 6.7611 seconds
# working on index #1330000
# Time taken by compute_tau_f_ is 6.7476 seconds
# working on index #1340000
# Time taken by compute_tau_f_ is 6.7761 seconds
# working on index #1350000
# Time taken by compute_tau_f_ is 6.8061 seconds
# working on index #1360000
# Time taken by compute_tau_f_ is 6.8090 seconds
# working on index #1370000
# Time taken by compute_tau_f_ is 6.7781 seconds
# working on index #1380000
# Time taken by compute_tau_f_ is 6.7298 seconds
# working on index #1390000
# Time taken by compute_tau_f_ is 6.7598 seconds
# working on index #1400000
# Time taken by compute_tau_f_ is 6.7857 seconds
# working on index #1410000
# Time taken by compute_tau_f_ is 6.7811 seconds
# working on index #1420000
# Time taken by compute_tau_f_ is 6.7415 seconds
# working on index #1430000
# Time taken by compute_tau_f_ is 6.7318 seconds
# working on index #1440000
# Time taken by compute_tau_f_ is 6.6995 seconds
# working on index #1450000
# Time taken by compute_tau_f_ is 6.7360 seconds
# working on index #1460000
# Time taken by compute_tau_f_ is 6.7816 seconds
# working on index #1470000
# Time taken by compute_tau_f_ is 6.7524 seconds
# working on index #1480000
# Time taken by compute_tau_f_ is 6.7570 seconds
# working on index #1490000
# Time taken by compute_tau_f_ is 6.7154 seconds
# working on index #1500000
# Time taken by compute_tau_f_ is 6.7579 seconds
# working on index #1510000
# Time taken by compute_tau_f_ is 6.7516 seconds
# working on index #1520000
# Time taken by compute_tau_f_ is 6.7437 seconds
# working on index #1530000
# Time taken by compute_tau_f_ is 6.7478 seconds
# working on index #1540000
# Time taken by compute_tau_f_ is 6.7724 seconds
# working on index #1550000
# Time taken by compute_tau_f_ is 6.7443 seconds
# working on index #1560000
# Time taken by compute_tau_f_ is 6.7358 seconds
# working on index #1570000
# Time taken by compute_tau_f_ is 6.7443 seconds
# working on index #1580000
# Time taken by compute_tau_f_ is 6.7729 seconds
# working on index #1590000
# Time taken by compute_tau_f_ is 6.7408 seconds
# working on index #1600000
# Time taken by compute_tau_f_ is 6.7171 seconds
# working on index #1610000
# Time taken by compute_tau_f_ is 6.7573 seconds
# working on index #1620000
# Time taken by compute_tau_f_ is 6.7481 seconds
# working on index #1630000
# Time taken by compute_tau_f_ is 6.7502 seconds
# working on index #1640000
# Time taken by compute_tau_f_ is 6.7651 seconds
# working on index #1650000
# Time taken by compute_tau_f_ is 6.7127 seconds
# working on index #1660000
# Time taken by compute_tau_f_ is 6.7196 seconds
# working on index #1670000
# Time taken by compute_tau_f_ is 6.7667 seconds
# working on index #1680000
# Time taken by compute_tau_f_ is 6.7665 seconds
# working on index #1690000
# Time taken by compute_tau_f_ is 6.7807 seconds
# working on index #1700000
# Time taken by compute_tau_f_ is 6.7446 seconds
# working on index #1710000
# Time taken by compute_tau_f_ is 6.7024 seconds
# working on index #1720000
# Time taken by compute_tau_f_ is 6.7991 seconds
# working on index #1730000
# Time taken by compute_tau_f_ is 6.7163 seconds
# working on index #1740000
# Time taken by compute_tau_f_ is 6.7373 seconds
# working on index #1750000
# Time taken by compute_tau_f_ is 6.7541 seconds
# working on index #1760000
# Time taken by compute_tau_f_ is 6.8315 seconds
# working on index #1770000
# Time taken by compute_tau_f_ is 6.8699 seconds
# working on index #1780000
# Time taken by compute_tau_f_ is 6.7955 seconds
# working on index #1790000
# Time taken by compute_tau_f_ is 6.8642 seconds
# working on index #1800000
# Time taken by compute_tau_f_ is 6.8472 seconds
# working on index #1810000
# Time taken by compute_tau_f_ is 6.8191 seconds
# working on index #1820000
# Time taken by compute_tau_f_ is 6.7794 seconds
# working on index #1830000
# Time taken by compute_tau_f_ is 6.7650 seconds
# working on index #1840000
# Time taken by compute_tau_f_ is 6.7849 seconds
# working on index #1850000
# Time taken by compute_tau_f_ is 6.7316 seconds
# working on index #1860000
# Time taken by compute_tau_f_ is 6.7470 seconds
# working on index #1870000
# Time taken by compute_tau_f_ is 6.7512 seconds
# working on index #1880000
# Time taken by compute_tau_f_ is 6.7295 seconds
# working on index #1890000
# Time taken by compute_tau_f_ is 6.7218 seconds
# working on index #1900000
# Time taken by compute_tau_f_ is 6.7797 seconds
# working on index #1910000
# Time taken by compute_tau_f_ is 6.7748 seconds
# working on index #1920000
# Time taken by compute_tau_f_ is 6.7085 seconds
# working on index #1930000
# Time taken by compute_tau_f_ is 6.7478 seconds
# working on index #1940000
# Time taken by compute_tau_f_ is 6.7731 seconds
# working on index #1950000
# Time taken by compute_tau_f_ is 6.7390 seconds
# working on index #1960000
# Time taken by compute_tau_f_ is 6.7164 seconds
# working on index #1970000
# Time taken by compute_tau_f_ is 6.7267 seconds
# working on index #1980000
# Time taken by compute_tau_f_ is 6.7344 seconds
# working on index #1990000
# Time taken by compute_tau_f_ is 6.7248 seconds
# working on index #2000000
# Time taken by compute_tau_f_ is 6.7742 seconds
# working on index #2010000
# Time taken by compute_tau_f_ is 6.7305 seconds
# working on index #2020000
# Time taken by compute_tau_f_ is 6.7604 seconds
# working on index #2030000
# Time taken by compute_tau_f_ is 6.7730 seconds
# working on index #2040000
# Time taken by compute_tau_f_ is 6.7518 seconds
# working on index #2050000
# Time taken by compute_tau_f_ is 6.7243 seconds
# working on index #2060000
# Time taken by compute_tau_f_ is 6.7340 seconds
# working on index #2070000
# Time taken by compute_tau_f_ is 6.7481 seconds
# working on index #2080000
# Time taken by compute_tau_f_ is 6.7556 seconds
# working on index #2090000
# Time taken by compute_tau_f_ is 6.7344 seconds
# working on index #2100000
# Time taken by compute_tau_f_ is 6.7385 seconds
# working on index #2110000
# Time taken by compute_tau_f_ is 6.7510 seconds
# working on index #2120000
# Time taken by compute_tau_f_ is 6.7377 seconds
# working on index #2130000
# Time taken by compute_tau_f_ is 6.7574 seconds
# working on index #2140000
# Time taken by compute_tau_f_ is 6.8667 seconds
# working on index #2150000
# Time taken by compute_tau_f_ is 6.9888 seconds
# working on index #2160000
# Time taken by compute_tau_f_ is 6.8183 seconds
# working on index #2170000
# Time taken by compute_tau_f_ is 6.7964 seconds
# working on index #2180000
# Time taken by compute_tau_f_ is 6.7762 seconds
# working on index #2190000
# Time taken by compute_tau_f_ is 6.7648 seconds
# working on index #2200000
# Time taken by compute_tau_f_ is 6.7684 seconds
# working on index #2210000
# Time taken by compute_tau_f_ is 6.7352 seconds
# working on index #2220000
# Time taken by compute_tau_f_ is 6.7811 seconds
# working on index #2230000
# Time taken by compute_tau_f_ is 6.7299 seconds
# working on index #2240000
# Time taken by compute_tau_f_ is 6.7701 seconds
# working on index #2250000
# Time taken by compute_tau_f_ is 6.8783 seconds
# working on index #2260000
# Time taken by compute_tau_f_ is 6.8168 seconds
# working on index #2270000
# Time taken by compute_tau_f_ is 6.7990 seconds
# working on index #2280000
# Time taken by compute_tau_f_ is 6.7777 seconds
# working on index #2290000
# Time taken by compute_tau_f_ is 6.7639 seconds
# working on index #2300000
# Time taken by compute_tau_f_ is 6.7482 seconds
# working on index #2310000
# Time taken by compute_tau_f_ is 6.7380 seconds
# working on index #2320000
# Time taken by compute_tau_f_ is 6.7278 seconds
# working on index #2330000
# Time taken by compute_tau_f_ is 6.7352 seconds
# working on index #2340000
# Time taken by compute_tau_f_ is 6.7399 seconds
# working on index #2350000
# Time taken by compute_tau_f_ is 6.7435 seconds
# working on index #2360000
# Time taken by compute_tau_f_ is 6.7499 seconds
# working on index #2370000
# Time taken by compute_tau_f_ is 6.8402 seconds
# working on index #2380000
# Time taken by compute_tau_f_ is 6.7662 seconds
# working on index #2390000
# Time taken by compute_tau_f_ is 6.7512 seconds
# working on index #2400000
# Time taken by compute_tau_f_ is 6.7466 seconds
# working on index #2410000
# Time taken by compute_tau_f_ is 6.7372 seconds
# working on index #2420000
# Time taken by compute_tau_f_ is 6.7207 seconds
# working on index #2430000
# Time taken by compute_tau_f_ is 6.7440 seconds
# working on index #2440000
# Time taken by compute_tau_f_ is 6.8039 seconds
# working on index #2450000
# Time taken by compute_tau_f_ is 6.7980 seconds
# working on index #2460000
# Time taken by compute_tau_f_ is 6.8134 seconds
# working on index #2470000
# Time taken by compute_tau_f_ is 6.8202 seconds
# working on index #2480000
# Time taken by compute_tau_f_ is 6.8025 seconds
# working on index #2490000
# Time taken by compute_tau_f_ is 6.7714 seconds
# working on index #2500000
# Time taken by compute_tau_f_ is 6.7929 seconds
# working on index #2510000
# Time taken by compute_tau_f_ is 6.7905 seconds
# working on index #2520000
# Time taken by compute_tau_f_ is 6.7484 seconds
# working on index #2530000
# Time taken by compute_tau_f_ is 6.7742 seconds
# working on index #2540000
# Time taken by compute_tau_f_ is 6.7359 seconds
# working on index #2550000
# Time taken by compute_tau_f_ is 6.7746 seconds
# working on index #2560000
# Time taken by compute_tau_f_ is 6.7883 seconds
# working on index #2570000
# Time taken by compute_tau_f_ is 6.7595 seconds
# working on index #2580000
# Time taken by compute_tau_f_ is 6.8083 seconds
# working on index #2590000
# Time taken by compute_tau_f_ is 6.7917 seconds
# working on index #2600000
# Time taken by compute_tau_f_ is 6.7495 seconds
# working on index #2610000
# Time taken by compute_tau_f_ is 6.7192 seconds
# working on index #2620000
# Time taken by compute_tau_f_ is 6.7944 seconds
# working on index #2630000
# Time taken by compute_tau_f_ is 6.7450 seconds
# working on index #2640000
# Time taken by compute_tau_f_ is 6.7324 seconds
# working on index #2650000
# Time taken by compute_tau_f_ is 6.7309 seconds
# working on index #2660000
# Time taken by compute_tau_f_ is 6.7639 seconds
# working on index #2670000
# Time taken by compute_tau_f_ is 6.7467 seconds
# working on index #2680000
# Time taken by compute_tau_f_ is 6.8158 seconds
# working on index #2690000
# Time taken by compute_tau_f_ is 6.9555 seconds
# working on index #2700000
# Time taken by compute_tau_f_ is 6.8015 seconds
# working on index #2710000
# Time taken by compute_tau_f_ is 6.7515 seconds
# working on index #2720000
# Time taken by compute_tau_f_ is 6.7518 seconds
# working on index #2730000
# Time taken by compute_tau_f_ is 6.7731 seconds
# working on index #2740000
# Time taken by compute_tau_f_ is 6.7725 seconds
# working on index #2750000
# Time taken by compute_tau_f_ is 6.7514 seconds
# working on index #2760000
# Time taken by compute_tau_f_ is 6.7522 seconds
# working on index #2770000
# Time taken by compute_tau_f_ is 6.7513 seconds
# working on index #2780000
# Time taken by compute_tau_f_ is 6.7340 seconds
# working on index #2790000
# Time taken by compute_tau_f_ is 6.8159 seconds
# working on index #2800000
# Time taken by compute_tau_f_ is 6.7656 seconds
# working on index #2810000
# Time taken by compute_tau_f_ is 6.7714 seconds
# working on index #2820000
# Time taken by compute_tau_f_ is 6.7768 seconds
# working on index #2830000
# Time taken by compute_tau_f_ is 6.7619 seconds
# working on index #2840000
# Time taken by compute_tau_f_ is 6.8093 seconds
# working on index #2850000
# Time taken by compute_tau_f_ is 6.8073 seconds
# working on index #2860000
# Time taken by compute_tau_f_ is 6.7523 seconds
# working on index #2870000
# Time taken by compute_tau_f_ is 6.7579 seconds
# working on index #2880000

# %%
tau_f = np.load(f'{model_tlr.save_folder}/tau_f_se.npy')
loss = np.load(f'{model_tlr.save_folder}/loss.npy')
iteration = np.load(f'{model_tlr.save_folder}/iteration.npy')

fig = plt.figure(figsize=(10.5, 5))
ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
j = idx(tau_f)
ax.plot(iteration[j], tau_f[j])
ax1.plot(iteration[j], np.log(loss[j]))
ax.set_xlabel('gradient descent step', fontsize=11)
ax1.set_xlabel('gradient descent step', fontsize=11)
ax.set_ylabel(r'$\mathbb{E}[\tau_f]$', fontsize=13)
ax1.set_ylabel(r'$\log(\mathcal{L})$', fontsize=11)
fig.subplots_adjust(wspace=.25)
fig.suptitle(r'$D_r=300, \beta=4\times10^{-5}, N=20000$')
plt.savefig('../data/plots/nn-rf-tiny-lrtau_f-loss.png', dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
model = srnn.SurrogateModel_NN(3, 300, save_folder=save_folder)
data = model.read()
ax.semilogy(data['iteration'], (data['learning_rate']))
ax.set_xlabel('gradient descent step', fontsize=11)
ax.set_ylabel(r'learning rate', fontsize=11)
ax.locator_params(nbins=8, axis='x')
plt.savefig('../data/plots/adaptive-lr-simple.png', dpi=300, bbox_inches='tight')

# %%
len(tau_f[j])
# Out:
# 150
