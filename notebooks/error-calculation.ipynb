# %%
import numpy as np 
from scipy.integrate import odeint
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import utility as ut
import microscope as mcr
import matplotlib.pyplot as plt
import pandas as pd
import surrogate1 as sr1

# %%
repo = '..'
save_folder = '{}/data/L63-Strategy-varying-features/'.format(repo)
D, D_r = 3, 300
Lyapunov_time, dt = 1./.91, 0.02
error_threshold = 0.05
beta = 4e-5
L0, L1 = 0.4, 3.5
percents = 50
row_selection = 'good_50_50'
train_option = 'random_20000'
n_repeats = 500
T = 220

L63_data_folder = '{}/data/L63-trajectories'.format(repo)
train = np.load('{}/train.npy'.format(L63_data_folder))
test = np.load('{}/test.npy'.format(L63_data_folder))[:100, :, :220]
limits_W_in, limits_W = [-0.1, 0.1], [-.5, .5]
for D_r in [2**n for n in [4, 5, 6, 7, 8, 9, 10, 11, 12]]:
  print('=======================================')
  print(f'Working with {D_r} features ...')
  print('=======================================')
  batch = sr1.BatchStrategyAnalyzer_SMLR(save_folder+str(D_r))
  batch.compute_mmmm()
# Out:
# =======================================
# Working with 16 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.09s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.08s
# Time taken by compute_mmmm is 6.2350 seconds
# =======================================
# Working with 32 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.08s
# Time taken by compute_mmmm is 6.2319 seconds
# =======================================
# Working with 64 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.09s
# Time taken by compute_mmmm is 6.3056 seconds
# =======================================
# Working with 128 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.10s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.09s
# Time taken by compute_mmmm is 6.3156 seconds
# =======================================
# Working with 256 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.11s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.12s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.10s
# Time taken by compute_mmmm is 7.2165 seconds
# =======================================
# Working with 512 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.13s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.11s
# Time taken by compute_mmmm is 7.8539 seconds
# =======================================
# Working with 1024 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.17s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.17s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.17s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.17s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.14s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.11s
# Time taken by compute_mmmm is 8.7752 seconds
# =======================================
# Working with 2048 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.21s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.17s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.15s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.13s
# Time taken by compute_mmmm is 9.7077 seconds
# =======================================
# Working with 4096 features ...
# =======================================
# Computing error for 0.0 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.02 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.04 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.06 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.08 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.1 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.12 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.14 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.16 good rows ...
# Time taken for batch of error computations = 0.23s
# Computing error for 0.18 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.2 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.22 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.24 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.26 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.28 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.3 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.32 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.34 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.36 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.38 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.4 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.42 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.44 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.46 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.48 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.5 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.52 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.54 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.56 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.58 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.6 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.62 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.64 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.66 good rows ...
# Time taken for batch of error computations = 0.21s
# Computing error for 0.68 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.7 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.72 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.74 good rows ...
# Time taken for batch of error computations = 0.20s
# Computing error for 0.76 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.78 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.8 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.82 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.84 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.86 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.88 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.9 good rows ...
# Time taken for batch of error computations = 0.19s
# Computing error for 0.92 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.94 good rows ...
# Time taken for batch of error computations = 0.18s
# Computing error for 0.96 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 0.98 good rows ...
# Time taken for batch of error computations = 0.16s
# Computing error for 1.0 good rows ...
# Time taken for batch of error computations = 0.14s
# Time taken by compute_mmmm is 10.5778 seconds
