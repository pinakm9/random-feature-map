# %%
import numpy as np 
from scipy.integrate import odeint
import os, sys, warnings
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import utility as ut
import surrogate1 as sr1
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from sklearn.linear_model import LinearRegression as LReg
from joblib import Parallel, delayed
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 14
#      12 import pandas as pd
#      13 from scipy import stats
# ---> 14 from sklearn.linear_model import LinearRegression as LReg
#      15 from joblib import Parallel, delayed
#      16 warnings.filterwarnings('ignore')
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# **Write FTLEs**

# %%
all_D_r = [2**n for n in range(2, 13)]
save_folder = '../data/L63-Strategy-varying-features/'
for D_r in all_D_r:
    print('Working on D_r = {}'.format(D_r))
    bsa = sr1.BatchStrategyAnalyzer_SMLR(save_folder+str(D_r))
    bsa.write_ftle(save_folder + '{}/ftle.npy'.format(D_r))
    # arr = np.load(bsa.save_folder + '/ftle.npy')
    # print(arr)
# Out:
# Working on D_r = 4
# Working on D_r = 8
# Working on D_r = 16
# Working on D_r = 32
# Working on D_r = 64
# Working on D_r = 128
# Working on D_r = 256
# Working on D_r = 512
# Working on D_r = 1024
# Working on D_r = 2048
# Working on D_r = 4096

# %% [markdown]
# **$\tau_f$ vs FTLE$^{-1}$**

# %%
D_r = 4096
bsa = sr1.BatchStrategyAnalyzer_SMLR(save_folder+str(D_r))
data = bsa.get_data()
sub_data = data[data['good_rows_W_in']==1.]
tau_f = sub_data['tau_f_se']
ftle = sub_data['ftle']
ftle1 = 1/ftle
# tau_f = (tau_f-tau_f.mean())/tau_f.std()
# ftle1 = (ftle1-ftle1.mean())/ftle1.std()
plt.hist(tau_f, density=True, label=r'$\tau_f$')
plt.hist(ftle1, density=True, alpha=0.7, label=r'$\frac{1}{\rm FTLE}$')
plt.hist(ftle, density=True, alpha=0.7, label=r'FTLE')
plt.legend()

# %%
plt.scatter(ftle, tau_f)

# %%
stats.pearsonr(tau_f, ftle)
# Out:
# PearsonRResult(statistic=-0.4402400989058427, pvalue=4.0607905155173605e-25)

# %%
len(np.unique(sub_data['test_index'].to_numpy()))
# Out:
# 480

# %%
plt.hist(ftle,  alpha=0.7, bins=10)
# Out:
# (array([ 10.,  48., 131., 184.,  98.,  18.,   8.,   2.,   0.,   1.]),
#  array([0.08539246, 0.31773709, 0.55008171, 0.78242633, 1.01477096,
#         1.24711558, 1.4794602 , 1.71180483, 1.94414945, 2.17649408,
#         2.4088387 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(tau_f, density=True, alpha=0.7)
# Out:
# (array([0.0078353 , 0.03721768, 0.0999001 , 0.19784137, 0.31145325,
#         0.2076355 , 0.07835302, 0.02154708, 0.00979413, 0.0078353 ]),
#  array([ 1.274  ,  2.29502,  3.31604,  4.33706,  5.35808,  6.3791 ,
#          7.40012,  8.42114,  9.44216, 10.46318, 11.4842 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(bsa.get_line('tau_f_se')[0], 1./bsa.get_line('ftle')[0])

# %%
x1 = data['good_rows_W_in']
x2 = data['ftle']
X = np.vstack([x1, x2]).T
y = data['tau_f_se']
res = stats.linregress(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 5
#       3 X = np.vstack([x1, x2]).T
#       4 y = data['tau_f_se']
# ----> 5 res = stats.linregress(X, y)
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/scipy/stats/_stats_mstats_common.py:167, in linregress(x, y, alternative)
#     162 ymean = np.mean(y, None)
#     164 # Average sums of square differences from the mean
#     165 #   ssxm = mean( (x-mean(x))^2 )
#     166 #   ssxym = mean( (x-mean(x)) * (y-mean(y)) )
# --> 167 ssxm, ssxym, _, ssym = np.cov(x, y, bias=1).flat
#     169 # R-value
#     170 #   r = ssxym / sqrt( ssxm * ssym )
#     171 if ssxm == 0.0 or ssym == 0.0:
#     172     # If the denominator was going to be 0
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/numpy/lib/function_base.py:2683, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2681     if not rowvar and y.shape[0] != 1:
#    2682         y = y.T
# -> 2683     X = np.concatenate((X, y), axis=0)
#    2685 if ddof is None:
#    2686     if bias == 0:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 2 and the array at index 1 has size 25500

# %%
np.vstack([x1, x2]).T
# Out:
# array([[0.        , 0.99502392],
#        [0.        , 0.91655952],
#        [0.        , 0.95371276],
#        ...,
#        [1.        , 0.99543237],
#        [1.        , 1.24080082],
#        [1.        , 0.72951538]])
