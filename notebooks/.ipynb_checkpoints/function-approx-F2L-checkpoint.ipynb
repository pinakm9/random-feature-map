# %%
import numpy as np 
from scipy.integrate import odeint
import os, sys, warnings
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import utility as ut
import surrogate_nn as srnn
import surrogate1 as sr1
import surrogate as sr
import matplotlib.pyplot as plt
import pandas as pd
import torch
from torch import nn
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, TensorDataset
from scipy import stats
import hr_restrict as hrr
import time
from torch.autograd.functional import jacobian
from torchdiffeq import odeint as odeint
from scipy.fft import fft, fftfreq
from scipy.linalg import dft
import seaborn as sns

# %%
np.random.seed(28)
def get_func(n1, n2):
    n = np.random.randint(n2, size=n1)
    a_n = np.random.normal(size=n1)
    b_n = np.random.normal(size=n1)
    return lambda x: np.array([a_n[i]*np.cos(n_*x) + b_n[i]*np.sin(n_*x) for i, n_ in enumerate(n)]).sum(axis=0)

yr = get_func(3, 10)
x = np.linspace(-np.pi, np.pi, 1000)

pi2 = 2*np.pi
y = lambda x:  5*np.sin(pi2*20*x) + 3*np.sin(pi2*30*x) + 0.1*np.sin(pi2*50*x) + 0.05*np.sin(pi2*40*x)
# Number of sample points
N = 1000
# sample spacing
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N, endpoint=False)
yf = fft(y(x))
xf = fftfreq(N, T)[:60]
plt.plot(xf, 2.0/N * np.abs(yf[:60]))

# %%
x = np.linspace(0., 0.1, int(1e6))
fx = y(x)
N = 20000
idx = np.sort(np.random.choice(len(x), size=N))
train_x = x[idx].reshape(1, -1)
train_y = fx[idx].reshape(1, -1)

sampler = hrr.GoodRowSampler(0.4, 3.5, train_x)
D_r=300
beta = 4e-9
# random feature map
Wb = sampler.sample(D_r)
rf = sr.SurrogateModel_LR(D=3, D_r=D_r, W_in_fn=Wb[:, :-1], b_in_fn=Wb[:, -1])
rf.compute_W_xy(train_x, train_y, beta)

fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

rf_y = rf.forecast_m(train_x).flatten()
ax1.scatter(train_x.flatten(), rf_y, s=1, label='RFM')
ax1.scatter(train_x.flatten(), train_y.flatten(), s=1, label='signal')
ax1.legend()
T = 1/1000
N = 50
rf_x = np.linspace(0.0, N*T, N, endpoint=False).reshape(1, -1)
rf_y = rf.forecast_m(rf_x).flatten()
yf = fft(rf_y)#fft(y(rf_x.flatten()))
xf = fftfreq(N, T)[:N//10]
ax2.plot(xf, 2.0/N * np.abs(yf[:N//10]), label='RFM')
ax2.set_xlabel('frequency')
ax2.legend()
# Out:
# Time taken by sample is 0.0051 seconds

# %%
plt.plot(x, y(x))

# %%
network = srnn.SurrogateModel_NN(D=1, D_r=300, save_folder='../data/func-approx')
log_interval = 100
save_interval = 1000
update_frequency = 100
min_change = (1-0.01)**(1./log_interval) - 1.
network.learn_xy(train_x, train_y, beta=4e-9, learning_rate=1e-4, steps=10000, batch_size=100,\
                 max_delta=0.1, min_change=min_change, constant_rate=False, update_frequency=update_frequency, mode='simple-random')
# Out:
# step: 0 loss: 1815.052494 time: 0.0021 lr: 0.000100,  change: nan%
# step: 100 loss: 2078.051171 time: 0.0764 lr: 0.000100,  change: 14.49%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step:

# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7300 loss: 1443.647275 time: 5.1866 lr: 0.000003,  change: 5.93%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7400 loss: 1923.959201 time: 5.2585 lr: 0.000003,  change: 41.17%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7500 loss: 1657.628974 time: 5.3305 lr: 0.000002,  change: 21.63%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7600 loss: 1403.575213 time: 5.4024 lr: 0.000002,  change: 2.99%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7700 loss: 1540.177531 time: 5.4735 lr: 0.000002,  change: 13.01%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7800 loss: 1290.737893 time: 5.5452 lr: 0.000002,  change: -5.29%
# step: 7900 loss: 1728.839454 time: 5.6164 lr: 0.000002,  change: 33.94%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8000 loss: 1358.363853 time: 5.6876 lr: 0.000002,  change: 5.24%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8100 loss: 1550.844952 time: 5.7599 lr: 0.000002,  change: 20.15%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8200 loss: 1599.671514 time: 5.8312 lr: 0.000002,  change: 23.93%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8300 loss: 1554.780527 time: 5.9017 lr: 0.000002,  change: 20.46%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8400 loss: 1729.760829 time: 5.9724 lr: 0.000002,  change: 34.01%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8500 loss: 1495.010699 time: 6.0437 lr: 0.000002,  change: 15.83%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8600 loss: 1542.959557 time: 6.1159 lr: 0.000002,  change: 19.54%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8700 loss: 1402.884496 time: 6.1868 lr: 0.000002,  change: 8.69%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8800 loss: 1548.197855 time: 6.2577 lr: 0.000002,  change: 19.95%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8900 loss: 1449.647642 time: 6.3291 lr: 0.000002,  change: 12.31%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9000 loss: 1746.128320 time: 6.4000 lr: 0.000001,  change: 35.28%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9100 loss: 1635.878212 time: 6.4721 lr: 0.000001,  change: 26.74%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9200 loss: 1566.106847 time: 6.5427 lr: 0.000001,  change: 21.33%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9300 loss: 1594.466394 time: 6.6141 lr: 0.000001,  change: 23.53%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9400 loss: 1604.823809 time: 6.6852 lr: 0.000001,  change: 24.33%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9500 loss: 1623.751446 time: 6.7563 lr: 0.000001,  change: 25.80%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9600 loss: 1263.190927 time: 6.8268 lr: 0.000001,  change: -2.13%
# step: 9700 loss: 1872.396492 time: 6.8977 lr: 0.000001,  change: 48.23%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9800 loss: 1665.300418 time: 6.9686 lr: 0.000001,  change: 31.83%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9900 loss: 1747.136240 time: 7.0403 lr: 0.000001,  change: 38.31%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# Time taken by learn_xy is 7.2943 seconds

# %%
fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

network_y = network.net(torch.from_numpy(train_x.T)).detach().numpy().flatten()
ax1.scatter(train_x.flatten(), network_y, s=1, label='NN')
ax1.scatter(train_x.flatten(), train_y, s=1, label='signal')
ax1.legend()
T = 1/1000
N = 50
network_x = np.linspace(0.0, N*T, N, endpoint=False).reshape(1, -1)
network_y = network.net(torch.from_numpy(network_x.T)).detach().numpy().flatten()
yf = fft(network_y)#fft(y(network_x.flatten()))
xf = fftfreq(N, T)[:N//2]
ax2.plot(xf, 2.0/N * np.abs(yf[:N//2]), label='RFM')
ax2.set_xlabel('frequency')
ax2.legend()

# %%
network = srnn.SurrogateModel_NN_multi(D=1, D_r=300, save_folder='../data/func-approx-multi')
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

network_y = network.net(torch.from_numpy(train_x.T)).detach().numpy().flatten()
ax1.scatter(train_x.flatten(), network_y, s=1, label='NN')
ax1.scatter(train_x.flatten(), train_y, s=1, label='signal')
ax1.legend()
T = 1/1000
N = 50
network_x = np.linspace(0.0, N*T, N, endpoint=False).reshape(1, -1)
network_y = network.net(torch.from_numpy(network_x.T)).detach().numpy().flatten()
yf = fft(network_y)#fft(y(network_x.flatten()))
xf = fftfreq(N, T)[:N//2]
ax2.plot(xf, 2.0/N * np.abs(yf[:N//2]), label='RFM')
ax2.set_xlabel('frequency')
ax2.legend()

# %%
network = srnn.SurrogateModel_NN_multi_bn(D=1, D_r=300, save_folder='../data/func-approx-multi-bn')
log_interval = 100
save_interval = 1000
update_frequency = 100
min_change = (1-0.01)**(1./log_interval) - 1.
network.learn_xy(train_x, train_y, beta=0., learning_rate=1e-5, steps=1000, batch_size=1000,\
                 max_delta=0.1, min_change=min_change, constant_rate=False, update_frequency=update_frequency, mode='simple-random')
# Out:
# step: 0 loss: 17795.714123 time: 0.0406 lr: 0.000010,  change: nan%
# step: 100 loss: 4034.781294 time: 1.8191 lr: 0.000010,  change: -77.33%
# step: 200 loss: 2086.437293 time: 3.5222 lr: 0.000010,  change: -48.29%
# step: 300 loss: 942.274969 time: 5.2823 lr: 0.000010,  change: -54.84%
# step: 400 loss: 610.617436 time: 7.0405 lr: 0.000010,  change: -35.20%
# step: 500 loss: 335.114532 time: 8.8002 lr: 0.000010,  change: -45.12%
# step: 600 loss: 377.367228 time: 10.5652 lr: 0.000010,  change: 12.61%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 700 loss: 251.267492 time: 12.3268 lr: 0.000009,  change: -25.02%
# step: 800 loss: 352.370850 time: 14.0914 lr: 0.000009,  change: 40.24%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 900 loss: 1371.655712 time: 15.8579 lr: 0.000009,  change: 445.89%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# Time taken by learn_xy is 17.6134 seconds

# %%
fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

network_y = network.net(torch.from_numpy(train_x.T)).detach().numpy().flatten()
ax1.scatter(train_x.flatten(), network_y, s=1, label='NN')
ax1.scatter(train_x.flatten(), train_y, s=1, label='signal')
ax1.legend()
T = 1/1000
N = 50
network_x = np.linspace(0.0, N*T, N, endpoint=False).reshape(1, -1)
network_y = network.net(torch.from_numpy(network_x.T)).detach().numpy().flatten()
yf = fft(network_y)#fft(y(network_x.flatten()))
xf = fftfreq(N, T)[:N//2]
ax2.plot(xf, 2.0/N * np.abs(yf[:N//2]), label='RFM')
ax2.set_xlabel('frequency')
ax2.legend()

# %%
network = srnn.SurrogateModel_NN_bn(D=1, D_r=300, save_folder='../data/func-approx-bn')
log_interval = 100
save_interval = 1000
update_frequency = 100
min_change = (1-0.01)**(1./log_interval) - 1.
network.learn_xy(train_x, train_y, beta=0., learning_rate=1e-5, steps=10000, batch_size=1000,\

# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7300 loss: 12621.853903 time: 33.8078 lr: 0.000000,  change: -0.27%
# step: 7400 loss: 13296.486437 time: 34.2666 lr: 0.000000,  change: 5.34%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7500 loss: 12890.895467 time: 34.7264 lr: 0.000000,  change: 2.13%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7600 loss: 12814.586979 time: 35.2392 lr: 0.000000,  change: 1.53%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7700 loss: 12927.426285 time: 35.6982 lr: 0.000000,  change: 2.42%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7800 loss: 13191.505708 time: 36.1568 lr: 0.000000,  change: 4.51%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 7900 loss: 12958.900921 time: 36.6190 lr: 0.000000,  change: 2.67%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8000 loss: 13438.721476 time: 37.0793 lr: 0.000000,  change: 6.47%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8100 loss: 13404.605204 time: 37.5381 lr: 0.000000,  change: 6.20%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8200 loss: 13594.787966 time: 37.9994 lr: 0.000000,  change: 7.71%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8300 loss: 13293.912233 time: 38.4676 lr: 0.000000,  change: 5.32%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8400 loss: 13637.476073 time: 38.9346 lr: 0.000000,  change: 8.05%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8500 loss: 13800.871611 time: 39.3940 lr: 0.000000,  change: 9.34%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8600 loss: 13020.688278 time: 39.8520 lr: 0.000000,  change: 3.16%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8700 loss: 13032.094757 time: 40.3095 lr: 0.000000,  change: 3.25%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8800 loss: 13408.802317 time: 40.7691 lr: 0.000000,  change: 6.23%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 8900 loss: 13423.172395 time: 41.2284 lr: 0.000000,  change: 6.35%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9000 loss: 13061.092906 time: 41.6853 lr: 0.000000,  change: 3.48%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9100 loss: 13657.707948 time: 42.1441 lr: 0.000000,  change: 8.21%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9200 loss: 13811.307803 time: 42.6032 lr: 0.000000,  change: 9.42%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9300 loss: 13604.429179 time: 43.0703 lr: 0.000000,  change: 7.78%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9400 loss: 13459.881266 time: 43.5289 lr: 0.000000,  change: 6.64%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9500 loss: 13874.714737 time: 43.9883 lr: 0.000000,  change: 9.93%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9600 loss: 13208.329930 time: 44.4543 lr: 0.000000,  change: 4.65%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9700 loss: 13134.153906 time: 44.9137 lr: 0.000000,  change: 4.06%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9800 loss: 13445.599864 time: 45.3727 lr: 0.000000,  change: 6.53%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# step: 9900 loss: 13164.340832 time: 45.8322 lr: 0.000000,  change: 4.30%
# --------------------------------------------------------------
#              Attempting to decrease learning rate
# --------------------------------------------------------------
# Time taken by learn_xy is 46.2877 seconds

# %%
fig = plt.figure(figsize=(10, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

network_y = network.net(torch.from_numpy(train_x.T)).detach().numpy().flatten()
ax1.scatter(train_x.flatten(), network_y, s=1, label='NN')
ax1.scatter(train_x.flatten(), train_y, s=1, label='signal')
ax1.legend()
T = 1/1000
N = 50
network_x = np.linspace(0.0, N*T, N, endpoint=False).reshape(1, -1)
network_y = network.net(torch.from_numpy(network_x.T)).detach().numpy().flatten()
yf = fft(network_y)#fft(y(network_x.flatten()))
xf = fftfreq(N, T)[:N//2]
ax2.plot(xf, 2.0/N * np.abs(yf[:N//2]), label='RFM')
ax2.set_xlabel('frequency')
ax2.legend()
